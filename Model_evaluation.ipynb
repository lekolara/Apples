# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
bias_set_HAM = xr.open_dataset('E://faks//cda//era5//bias_monthly_7.nc').__xarray_dataarray_variable__

# %%
bias_set_NOAA = xr.open_dataset('E://faks//cda//era5//bias_monthly_NOAA.nc').__xarray_dataarray_variable__

# %%
I have

# %%
fig, ax = plt.subplots(figsize=(10, 6))
plt.title("Montlhy difference between models and ERA5")
ax.set_ylabel('Bias')
bias_set_HAM.plot(ax=ax, color='cornflowerblue', label='MPI-ESM1.2-HAM')
bias_set_NOAA.plot(ax=ax,color='darksalmon', label='GFDL-ESM4')
ax.axhline(0, color='k')
ax.legend(loc='upper right')
plt.show()

# %%
bias_set_HAM
# Out:
# <xarray.Dataset>
# Dimensions:                        (month: 7)
# Coordinates:
#     latitude                       int32 ...
#     longitude                      int32 ...
#   * month                          (month) int64 1 2 3 4 10 11 12
#     height                         float64 ...
#     lat                            int32 ...
#     lon                            int32 ...
# Data variables:
#     __xarray_dataarray_variable__  (month) float64 ...
